# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # Series using read_csv

# %%
#with one col
file1 = pd.read_csv(r'C:\Users\Hp\Downloads\subs.csv').squeeze()
file1
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
type(file1)
# Out:
# pandas.core.series.Series

# %%
file2 = pd.read_csv(r"C:\Users\Hp\Downloads\kohli_ipl.csv",index_col = 'match_no').squeeze()
file2
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
type(file2)
# Out:
# pandas.core.series.Series

# %%
movies = pd.read_csv(r"C:\Users\Hp\Downloads\bollywood.csv", index_col='movie').squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # Series Methods

# %%
# head and tail--> return first 5 or last 5 rows by default from file
file1.head()
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# Name: Subscribers gained, dtype: int64

# %%
file2.tail()
# Out:
# match_no
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, dtype: int64

# %%
file1.head(7)
# Out:
# 0    48
# 1    57
# 2    40
# 3    43
# 4    44
# 5    46
# 6    33
# Name: Subscribers gained, dtype: int64

# %%
# sample --> Gives randomly a row from Dataset
movies.sample(3)
# Out:
# movie
# Rustom (film)                          Ileana D'Cruz
# Ek Second... Jo Zindagi Badal De?    Bhushan Agarwal
# Sabki Bajegi Band                      Swara Bhaskar
# Name: lead, dtype: object

# %%
# value count
movies.value_counts()
# Out:
# lead
# Akshay Kumar          48
# Amitabh Bachchan      45
# Ajay Devgn            38
# Salman Khan           31
# Sanjay Dutt           26
#                       ..
# Talha Arshad Reshi     1
# Garima Agarwal         1
# Rasika Agashe          1
# Zaheer Iqbal           1
# Deepika Amin           1
# Name: count, Length: 566, dtype: int64

# %%
# sorting
file2.sort_values(ascending = False).head(1).values[0]
# Out:
# np.int64(113)

# %%
# sort_index sort data based on index and inplace parameter edit original data
movies.sort_index(inplace=True)
movies
# Out:
# movie
# 1920 (film)                   Rajniesh Duggall
# 1920: London                     Sharman Joshi
# 1920: The Evil Returns             Vicky Ahuja
# 1971 (2007 film)                Manoj Bajpayee
# 2 States (2014 film)              Arjun Kapoor
#                                    ...
# Zindagi 50-50                      Veena Malik
# Zindagi Na Milegi Dobara        Hrithik Roshan
# Zindagi Tere Naam           Mithun Chakraborty
# Zokkomon                       Darsheel Safary
# Zor Lagaa Ke...Haiya!            Meghan Jadhav
# Name: lead, Length: 1500, dtype: object

# %% [markdown]
# # Seies Math functions

# %%
# count --> Count Non-Null values in data 
file1.count().item()
# Out:
# 365

# %%
# sum 
file1.sum().item()
# Out:
# 49510

# %%
# mean -> median -> mode -> std -> var
print(file2.mean())
print(file2.median())
print(file2.std()) 
print(file2.var())
print(file2.mode())
# Out:
# 30.855813953488372
# 24.0
# 26.22980132830278
# 688.0024777222344
# 0    0
# Name: runs, dtype: int64

# %%
# describe -> Give description about data 
file1.describe()
# Out:
# count    365.000000
# mean     135.643836
# std       62.675023
# min       33.000000
# 25%       88.000000
# 50%      123.000000
# 75%      177.000000
# max      396.000000
# Name: Subscribers gained, dtype: float64

# %%
# min -> max 
file1.max()
# Out:
# 396

# %%
file1.min()
# Out:
# 33

# %%
product = file1.astype(object).product() 
product
# Out:
# ...
